# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
names = [
    "d1_bends",
    "d1_finishes",
    "d1_speed",
    "d1_sp",
    "d1_work",
    "d2_bends",
    "d2_finishes",
    "d2_speed",
    "d2_sp",
    "d2_work",
    "result"
]
races = pd.read_csv("data/data_train.csv", names=names)

# %%
results = races["result"]
del races["result"]
data = pd.DataFrame()
data["s1"] = races["d1_speed"]
data["s2"] = races["d2_speed"]
data["sp"] = races["sp"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-fd6246995228> in <module>()
#       2 del races["result"]
#       3 data = []
# ----> 4 data["s1"] = races["d1_speed"]
#       5 data["s2"] = races["d2_speed"]
#       6 data["sp"] = races["sp"]
#
# TypeError: list indices must be integers, not str

# %%
races.shape
# Out:
# (13941, 10)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_X = scaler.fit_transform(races)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=10)

# %%
x_pca = pca.fit_transform(scaled_X)

# %%
plt.figure(figsize=(12,8))
plt.scatter(x_pca[:,0], x_pca[:,6], c=results)
