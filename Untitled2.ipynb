# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
races = pd.read_csv("data/data_train.csv", names=["b1","b2","b3","r1","r2","f1","f2","sp","w","y","l","result"])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
results = races["result"]
data = pd.DataFrame()
data["sp"] = races["sp"]
data["w"] = races["w"]
data["l"] = races["l"]
data["y"] = races["y"]

# %%
data.head()
# Out:
#      sp     w   l    y
# 0   5.0  27.4   7  3.0
# 1   4.2  28.8   9  2.0
# 2   3.9  25.8   9  2.0
# 3  10.8  23.7   4  3.0
# 4   3.7  32.5  11  2.0

# %%
scaler = StandardScaler()

# %%
scaled_X = scaler.fit_transform(data)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
x_pca = pca.fit_transform(scaled_X)

# %%
plt.figure(figsize=(12,8))
plt.scatter(x_pca[:,0], x_pca[:,1], c=results)
